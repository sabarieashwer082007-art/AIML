# %% [markdown]
# <a href="https://colab.research.google.com/github/sabarieashwer082007-art/AIML/blob/main/logistic_regression_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step 1: Import libraries
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# Step 2: Create dataset
data = {
    'Hours': [1, 2, 3, 4, 5, 6, 7, 8],
    'Pass':  [0, 0, 0, 0, 1, 1, 1, 1]   # 0 = Fail, 1 = Pass
}

df = pd.DataFrame(data)

# Step 3: Define X and y
X = df[['Hours']]
y = df['Pass']

# Step 4: Create model
model = LogisticRegression()

# Step 5: Train model
model.fit(X, y)

# Step 6: Predict
predictions = model.predict(X)

# Step 7: Accuracy
print("Predictions:", predictions)
print("Accuracy:", accuracy_score(y, predictions))

# Step 8: Graph
plt.scatter(X, y)
plt.xlabel("Hours Studied")
plt.ylabel("Pass (0 = Fail, 1 = Pass)")
plt.title("Logistic Regression")
plt.show()
# Out:
# Predictions: [0 0 0 0 1 1 1 1]
# Accuracy: 1.0
